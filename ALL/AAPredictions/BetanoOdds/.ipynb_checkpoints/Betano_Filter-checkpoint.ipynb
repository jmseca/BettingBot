# %%
import pandas as pd
import numpy as np
import time
import os
import datetime as dt
from functools import reduce
import unidecode #para tirar os acentos e "ç"
import re

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %%
df0 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano0.csv')
df1 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano1.csv')

# %%
leagues_betano = {
    'Championship':'Championship', 'LaLiga':'La_Liga',
    'Liga Europa - Jogos':'Liga_Europa','Liga dos Campeões - Jogos':'Champions',
    'MLS':'MLS','Premier League' : 'Premier_League',
    'Premier Liga':'RFPL','Premiership':'Premiership',
    'Primeira Liga':'Primeira_Liga','Série A': 'Serie_A'
}

# %%
def Betano_date(x):
    months = {
        'Janeiro':1,'Fevereiro':2,'Março':3,'Abril':4,'Maio':5,'Junho':6,
        'Julho':7,'Agosto':8,'Setembro':9,'Outubro':10,'Novembro':11,'Dezembro':12
    }
    try:
        x = x.split(', ')[1]
        day,month,year,time=x.split(' ')
        #date
        if month not in months:
            print(month)
            month = input('Qual é o mês?   ')
        else:
            month = months[month]
        date = dt.datetime.strptime(str(day)+'/'+str(month)+'/'+str(year),'%d/%m/%Y')
        #time
        h,m=time.split(':')
        H=int(h)*100
        time = H+int(m)
        return date,time
    except:
        return 'None','None'

def Betano_league(x,leagues):
    if x not in leagues:
        print(x)
        return 'None'
    else:
        return leagues[x]
    
def Betano_nan(df): #remove os scrapes falhados
    lig=list(np.where(df['League'].isnull().values)[0])
    rest=list(np.where(np.logical_and(df['Date'].isnull().values,df['HomeTeam'].isnull().values,
                                     df['AwayTeam'].isnull().values))[0])
    dele = list(np.unique(np.array(lig+rest)))
    print(dele)
    df=df.drop(dele,axis=0).reset_index(drop=True)
    return df

# %%
def europe_filter(df):
    for i in range(len(df)):
        if (df.iloc[i]['League']=='Liga_Europa') or (df.iloc[i]['League']=='Champions'):
            for c in list(df.columns[8:-2]):
                df.at[i,c]='None'
    return df

# %%
def Betano_filter(df,l=leagues_betano):
    df = Betano_nan(df)
    Dates = [df.iloc[i]['Date'] for i in range(len(df))]
    date_time = list(map(Betano_date,Dates))
    
    try:
        sDates = [df.iloc[i]['Current_Date'] for i in range(len(df))]
        sdate_time = list(map(Betano_date,sDates))
    except:
        pass
    
    Leag = [df.iloc[i]['League'] for i in range(len(df))]
    League = list(map(Betano_league,Leag,[l]*len(Leag)))
    Y25=[]
    N25=[]
    YBS=[]
    NBS=[]
    X1=[]
    _12=[]
    X2=[]
    for i in range(len(df)):
        #25
        if df.iloc[i]['Tag25']=='Mais de2.5':
            Y25+=[df.iloc[i]['ODD_25+']]
            N25+=[df.iloc[i]['ODD_25-']]
        elif df.iloc[i]['Tag15']=='Mais de2.5':
            Y25+=[df.iloc[i]['ODD_15+']]
            N25+=[df.iloc[i]['ODD_15-']]
        elif df.iloc[i]['Tag35']=='Mais de2.5':
            Y25+=[df.iloc[i]['ODD_35+']]
            N25+=[df.iloc[i]['ODD_35-']]
        else:
            if (df.iloc[i]['League']=='Liga Europa - Jogos') or (df.iloc[i]['League']=='Liga dos Campeões - Jogos'):
                Y25+=['None']
                N25+=['None']
            else:
                print(df.iloc[i]['League'],i)
                print('problema com 25')
                print('---------------')
                Y25+=['None']
                N25+=['None']
            
        #BS
        if df.iloc[i]['TagBS']=='Ambas Equipas Marcam (Sim/Não)':
            YBS+=[df.iloc[i]['ODD_BthScore_Yes']]
            NBS+=[df.iloc[i]['ODD_BthScore_No']]
        else:
            if (df.iloc[i]['League']=='Liga Europa - Jogos') or (df.iloc[i]['League']=='Liga dos Campeões - Jogos'):
                YBS+=['None']
                NBS+=['None']
            else:
                print(df.iloc[i]['League'],i)
                print('problema com BS')
                print('---------------')
                YBS+=['None']
                NBS+=['None']
            
        #DC
        if df.iloc[i]['Tag1X']=='1X':
            X1+=[df.iloc[i]['ODD_1X']]
        elif df.iloc[i]['Tag12']=='1X':
            X1+=[df.iloc[i]['ODD_12']]
        elif df.iloc[i]['TagX2']=='1X':
            X1+=[df.iloc[i]['ODD_X2']]
        else:
            X1+=['None']
        #--------------------------------------------------   
        if df.iloc[i]['Tag1X']=='12':
            _12+=[df.iloc[i]['ODD_1X']]
        elif df.iloc[i]['Tag12']=='12':
            _12+=[df.iloc[i]['ODD_12']]
        elif df.iloc[i]['TagX2']=='12':
            _12+=[df.iloc[i]['ODD_X2']]
        else:
            _12+=['None']    
        #---------------------------------------------------
        if df.iloc[i]['Tag1X']=='2X':
            X2+=[df.iloc[i]['ODD_1X']]
        elif df.iloc[i]['Tag12']=='2X':
            X2+=[df.iloc[i]['ODD_12']]
        elif df.iloc[i]['TagX2']=='2X':
            X2+=[df.iloc[i]['ODD_X2']]
        else:
            X2+=['None']
            
    ODDH = list(df.iloc[:]['ODDH'])
    ODDD = list(df.iloc[:]['ODDD'])
    ODDA = list(df.iloc[:]['ODDA'])
    Date = [date_time[i][0] for i in range(len(date_time))]
    Time = [date_time[i][1] for i in range(len(date_time))]
    
    try:
        sDate = [sdate_time[i][0] for i in range(len(sdate_time))]
        sTime = [sdate_time[i][1] for i in range(len(sdate_time))]
    except:
        pass
    
    HT = list(map(lambda x:unidecode.unidecode(x),list(df.iloc[:]['HomeTeam'])))
    AT = list(map(lambda x:unidecode.unidecode(x),list(df.iloc[:]['AwayTeam'])))
    
    try:
        df = pd.DataFrame({
            'League':League,'Date':Date,'Time':Time,
            'HT':HT,'AT':AT,'ODDH':ODDH,'ODDD':ODDD,'ODDA':ODDA,
            'ODD_25+':Y25,'ODD_25-':N25,
            'ODD_BthScore_Yes':YBS,'ODD_BthScore_No':NBS,
            'ODD_1X':X1,'ODD_12':_12,'ODD_X2':X2,
            'Scrape_Date':sDate,'Scrape_Time':sTime
        })
    except:
        df = pd.DataFrame({
            'League':League,'Date':Date,'Time':Time,
            'HT':HT,'AT':AT,'ODDH':ODDH,'ODDD':ODDD,'ODDA':ODDA,
            'ODD_25+':Y25,'ODD_25-':N25,
            'ODD_BthScore_Yes':YBS,'ODD_BthScore_No':NBS,
            'ODD_1X':X1,'ODD_12':_12,'ODD_X2':X2
        })
    
    df = europe_filter(df)
    
    return df.sort_values(['Date','Time'],ascending=[True,True]).reset_index(drop=True)


def mergeB_year(x):
    x=x.split('-')
    return x[0]
    
def mergeB_month(x): #não vou usar por causa daquele pequeno erro da falhas das datas no último dia do mês
    x=x.split('-')
    return x[1]
    
def merge_Betano(w): #w é uma lista de dfs
#se encontrarmos o mesmo jogo, escolhemos a odd + baixa (da ODDH)
    df = pd.concat(w,sort=False).sort_values(['Date','Time'],ascending=[True,True]).reset_index(drop=True)
    i=0
    while i<len(df):
        same = list(np.where(np.logical_and(
        np.logical_and(df['HT']==df.iloc[i]['HT'],df['AT']==df.iloc[i]['AT']),
        np.logical_and(np.array(list(map(lambda x:mergeB_year(x),df['Date'])))==mergeB_year(df.iloc[i]['Date']),
        df['League']==df.iloc[i]['League'])))[0])
        if len(same)==1:
            i+=1
        else:
            ind=np.argmin([df.iloc[i]['ODDH'] for i in same])
            del same[ind]
            df = df.drop(same,axis=0).reset_index(drop=True)
            #!!!!!!!!!!!!!!!!!!!!!        
            #Se precisar do 25 e do BS, mudar este merge, para tentar ter um q não tenha 'None' nessas odds
            #!!!!!!!!!!!!!!!!!!!!!!
    return df


def Betano_timediff(df,i): #damos a df e o índice e devolve a diferença entre scrape time e game time (+/- em horas)
    scrape_date = dt.datetime.strptime(df.iloc[i]['Scrape_Date'],'%Y-%m-%d')
    scrape_time = df.iloc[i]['Scrape_Time']
    date = dt.datetime.strptime(df.iloc[i]['Date'],'%Y-%m-%d')
    time = df.iloc[i]['Time']
    sh,sm = str(scrape_time)[0:2],str(scrape_time)[2:4]
    h,m = str(time)[0:2],str(time)[2:4]
    dt_ok = date + dt.timedelta(hours=int(h),minutes=int(m))
    dt_scrape = scrape_date + dt.timedelta(hours=int(sh),minutes=int(sm))
    final = dt_ok-dt_scrape
    return ((final.days*86400)+(final.seconds))//3600


def Betano_odd(w,odd='ODDH',x=3): #devolve uma df com o top "x" de Odds do evento "odd"
    df = pd.concat(w,sort=False).sort_values(['Date','Time'],ascending=[True,True]).reset_index(drop=True)
    for n in range(1,x+1):
        vars()[odd+'_TOP'+str(n)]=[]
        vars()['Time_'+str(n)]=[]
    HT=[]
    AT=[]
    Lig=[]
    Dt=[]
    Tm=[]
    i=0
    done_is=[]
    while i<len(df):
        if i in done_is:
            i+=1
            continue
        same = list(np.where(np.logical_and(
        np.logical_and(df['HT']==df.iloc[i]['HT'],df['AT']==df.iloc[i]['AT']),
        np.logical_and(np.array(list(map(lambda x:mergeB_year(x),df['Date'])))==mergeB_year(df.iloc[i]['Date']),
        np.array(list(map(lambda x:mergeB_month(x),df['Date'])))==mergeB_month(df.iloc[i]['Date']))))[0])
        if len(same)==1:
            for n in range(1,x+1):
                if n==1:
                    vars()[odd+'_TOP'+str(n)]+=[df.iloc[i]['ODDH']]
                    vars()['Time_'+str(n)]+=[Betano_timediff(df,i)] #diff em horas do game time e scrape time
                else:
                    vars()[odd+'_TOP'+str(n)]+=['None']
                    vars()['Time_'+str(n)]+=['None']
            HT+=[df.iloc[same[0]]['HT']]
            AT+=[df.iloc[same[0]]['AT']]
            Lig+=[df.iloc[same[0]]['League']]
            Dt+=[df.iloc[same[0]]['Date']]
            Tm+=[df.iloc[same[0]]['Time']]
        else:
            oddsH=[df.iloc[s]['ODDH'] for s in same]
            oddsH_=list(map(lambda x:-x,oddsH))
            sorte=np.argsort(oddsH_) #assim fazemos reverse sort
            i2=1
            while (i2<=x):
                if ((i2-1)<len(sorte)):
                    vars()[odd+'_TOP'+str(i2)]+=[oddsH[sorte[i2-1]]]
                    vars()['Time_'+str(i2)]+=[Betano_timediff(df,same[sorte[i2-1]])]
                else:
                    vars()[odd+'_TOP'+str(i2)]+=['None']
                    vars()['Time_'+str(i2)]+=['None']
                i2+=1
            HT+=[df.iloc[same[0]]['HT']]
            AT+=[df.iloc[same[0]]['AT']]
            Lig+=[df.iloc[same[0]]['League']]
            Dt+=[df.iloc[same[0]]['Date']]
            Tm+=[df.iloc[same[0]]['Time']]
                
            
        done_is+=same
        i+=1
    
    odd_df=pd.DataFrame({'League':Lig,'HT':HT,'AT':AT,'Date':Dt,'Time':Tm})
    for n in range(1,x+1):
        odd_df[odd+'_TOP'+str(n)]=vars()[odd+'_TOP'+str(n)]
        odd_df['Time_'+str(n)]=vars()['Time_'+str(n)]
    
    return odd_df


            
def save_filterBetano(w):
    oo=os.listdir('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data')
    if oo!=[]:
        i1 = int(oo[-1][-5])
        w.to_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano'+str(i1+1)+'.csv',index=False)            
    else:
        w.to_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano0.csv',index=False)
        

def Betano_autofilter():
#verifica quais as dfs q estão no filter data, e faz o filter das dfs que ainda não foram filtered
    dir1 = os.listdir('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds')
    dfs = [dir1[i] for i in range(len(dir1)) if ('betano' in dir1[i]) and ('Pre' not in dir1[i])]
    dir2 = os.listdir('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data')
    last = len(dir2) 
    dfs = dfs[last:]
    print(dir1)
    raise áa
    for n in range(len(dfs)):
        dff = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//'+str(dfs[n]))
        Df = Betano_filter(dff)
        save_filterBetano(Df)

# %%
Betano_autofilter()
# Out:
# ['.ipynb_checkpoints', 'ATENÇÃO.txt', 'betano0.csv', 'betano1.csv', 'betano10.csv', 'betano11.csv', 'betano12.csv', 'betano13.csv', 'betano2.csv', 'betano3.csv', 'betano4.csv', 'betano5.csv', 'betano6.csv', 'betano7.csv', 'betano8.csv', 'betano9.csv', 'Betano_Filter.ipynb', 'Filtered_Data', 'Merged_Data', 'Pre_betano.csv']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-dc31f5449a96> in <module>
# ----> 1 Betano_autofilter()
#
# <ipython-input-16-4530e5059e37> in Betano_autofilter()
#     246     dfs = dfs[last:]
#     247     print(dir1)
# --> 248     raise áa
#     249     for n in range(len(dfs)):
#     250         dff = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//'+str(dfs[n]))
#
# NameError: name 'áa' is not defined

# %%
df = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano0.csv')

# %%
type(df.iloc[0]['Date'])==str
# Out:
# True

# %%
a = ['None','None','None','None','None','None',2]
np.where(np.array(a)=='None')[0].any()
# Out:
# True

# %%
dir1
# Out:
# ['Betano0.csv',
#  'Betano1.csv',
#  'Betano2.csv',
#  'Betano3.csv',
#  'Betano4.csv',
#  'Betano5.csv',
#  'Betano6.csv',
#  'Betano7.csv',
#  'Betano8.csv']

# %%
dir1 = os.listdir('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data')
dir2 = [pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//'+dir1[i]) for i in range(len(dir1))]
mdf=merge_Betano(dir2)

# %%
mdf
# Out:
#      Unnamed: 0          League        Date  Time                         HT  \
# 0            28  Premier_League  2020-07-19  1400                Bournemouth
# 1            66    Championship  2020-07-19  1400               Derby County
# 2            22    Championship  2020-07-19  1500                Barnsley FC
# 3            73  Premier_League  2020-07-19  1600                  Tottenham
# 4            81         La_Liga  2020-07-19  1600                     Alaves
# 5            43         Serie_A  2020-07-19  1615                      Parma
# 6            17         La_Liga  2020-07-19  1730                 Villarreal
# 7            36         La_Liga  2020-07-19  1730            Real Valladolid
# 8             1         Serie_A  2020-07-19  1830                 Fiorentina
# 9            19         Serie_A  2020-07-19  1830                    Napoles
# 10           30         Serie_A  2020-07-19  1830                     Genova
# 11           46            RFPL  2020-07-19  1830                  Krasnodar
# 12           88         Serie_A  2020-07-19  1830             Brescia Calcio
# 13           15   Primeira_Liga  2020-07-19  1900             Belenenses SAD
# 14            8         La_Liga  2020-07-19  2000                    Sevilha
# 15           24         La_Liga  2020-07-19  2000                 CA Osasuna
# 16           40         La_Liga  2020-07-19  2000                    Leganes
# 17           41         La_Liga  2020-07-19  2000                    Levante
# 18           42         La_Liga  2020-07-19  2000                   Espanhol
# 19           78         La_Liga  2020-07-19  2000         Atletico de Madrid
# 20           86         La_Liga  2020-07-19  2000                 Granada CF
# 21           72         Serie_A  2020-07-19  2045                    AS Roma
# 22           82   Primeira_Liga  2020-07-19  2115          Vitoria Guimaraes
# 23           68             MLS  2020-07-20   100               Chicago Fire
# 24           54             MLS  2020-07-20   330           Seattle Sounders
# 25           32             MLS  2020-07-20  1400             Inter Miami CF
# 26           79   Primeira_Liga  2020-07-20  1700             Pacos Ferreira
# 27           50  Premier_League  2020-07-20  1800                   Brighton
# 28           74  Premier_League  2020-07-20  1800           Sheffield United
# 29            0   Primeira_Liga  2020-07-20  1915                    Tondela
# 30           69  Premier_League  2020-07-20  2015              Wolverhampton
# 31            4         Serie_A  2020-07-20  2045                   Juventus
# 32           49   Primeira_Liga  2020-07-20  2115                   FC Porto
# 33           16             MLS  2020-07-21   100         Philadelphia Union
# 34           47             MLS  2020-07-21  1400                 Toronto FC
# 35           55  Premier_League  2020-07-21  1800                    Watford
# 36           60         Serie_A  2020-07-21  1830                   Atalanta
# 37           59   Primeira_Liga  2020-07-21  1900                Sporting CP
# 38            6  Premier_League  2020-07-21  2015                Aston Villa
# 39           70         Serie_A  2020-07-21  2045                   Sassuolo
# 40           57   Primeira_Liga  2020-07-21  2115                 Desp. Aves
# 41           80             MLS  2020-07-22   100             Atlanta United
# 42           49             MLS  2020-07-22   330            Montreal Impact
# 43            5             MLS  2020-07-22  1400             Real Salt Lake
# 44           90            RFPL  2020-07-22  1700             Dinamo Moscovo
# 45           26            RFPL  2020-07-22  1700               CSKA Moscovo
# 46           51            RFPL  2020-07-22  1700                Rubin Kazan
# 47           68            RFPL  2020-07-22  1700                     Rostov
# 48           40            RFPL  2020-07-22  1700                     FC Ufa
# 49           44            RFPL  2020-07-22  1700  Ural Sverdlovskaya Oblast
# 50           54            RFPL  2020-07-22  1700                  Krasnodar
# 51           10  Premier_League  2020-07-22  1800          Manchester United
# 52           27         Serie_A  2020-07-22  1830                      Parma
# 53            3    Championship  2020-07-22  1930                 Luton Town
# 54           11    Championship  2020-07-22  1930               Bristol City
# 55           18    Championship  2020-07-22  1930                    Cardiff
# 56           67    Championship  2020-07-22  1930               Brentford FC
# 57           76    Championship  2020-07-22  1930          Nottingham Forest
# 58           77    Championship  2020-07-22  1930        Sheffield Wednesday
# 59           85    Championship  2020-07-22  1930                  West Brom
# 60           21    Championship  2020-07-22  1930                      Wigan
# 61            5    Championship  2020-07-22  1930               Leeds United
# 62            8    Championship  2020-07-22  1930                    Reading
# 63           50    Championship  2020-07-22  1930                 Birmingham
# 64           60    Championship  2020-07-22  1930                Millwall FC
# 65            2  Premier_League  2020-07-22  2015                  Liverpool
# 66           38         Serie_A  2020-07-22  2045                       Spal
# 67           65         Serie_A  2020-07-22  2045                     Torino
# 68           87         Serie_A  2020-07-22  2045                  Sampdoria
# 69           59         Serie_A  2020-07-22  2045             Inter de Milao
# 70           55         Serie_A  2020-07-22  2045                   US Lecce
# 71            6             MLS  2020-07-23   100              FC Cincinnati
# 72            9             MLS  2020-07-23   330            Colorado Rapids
# 73           20             MLS  2020-07-23  1400               Chicago Fire
# 74           57         Serie_A  2020-07-23  1830                    Udinese
# 75            2         Serie_A  2020-07-23  2045                      Lazio
# 76           34             MLS  2020-07-24   100         Los Angeles Galaxy
# 77           20             MLS  2020-07-24   330             Los Angeles FC
# 78           26   Primeira_Liga  2020-07-24  1900                Santa Clara
# 79            6         Serie_A  2020-07-24  2045                   AC Milao
# 80           23   Primeira_Liga  2020-07-24  2115                Gil Vicente
# 81            8         Serie_A  2020-07-25  1615             Brescia Calcio
# 82            3         Serie_A  2020-07-25  1830                     Genova
# 83           15   Primeira_Liga  2020-07-25  1900                   Boavista
# 84           71   Primeira_Liga  2020-07-25  1900                   Maritimo
# 85            6         Serie_A  2020-07-25  2045                    Napoles
# 86           41   Primeira_Liga  2020-07-25  2115                   SC Braga
# 87            1   Primeira_Liga  2020-07-25  2115                 SL Benfica
# 88            9             MLS  2020-07-26   100            Orlando City SC
# 89           10             MLS  2020-07-26   330         Philadelphia Union
# 90           38  Premier_League  2020-07-26  1600          Crystal Palace FC
# 91           20  Premier_League  2020-07-26  1600                  Leicester
# 92           14  Premier_League  2020-07-26  1600                    Chelsea
# 93            6  Premier_League  2020-07-26  1600                    Arsenal
# 94            7  Premier_League  2020-07-26  1600                Southampton
# 95            8  Premier_League  2020-07-26  1600            Manchester City
# 96            9  Premier_League  2020-07-26  1600                    Everton
# 97           11  Premier_League  2020-07-26  1600                    Burnley
# 98            4  Premier_League  2020-07-26  1600                  Newcastle
# 99            9  Premier_League  2020-07-26  1600                   West Ham
# 100          25         Serie_A  2020-07-26  1615                    Bolonha
# 101          27         Serie_A  2020-07-26  1830                   Cagliari
# 102          30    Championship  2020-07-26  1830               Swansea City
# 103          26         Serie_A  2020-07-26  1830              Hellas Verona
# 104          12         Serie_A  2020-07-26  1830                       Spal
# 105          13         Serie_A  2020-07-26  1830                    AS Roma
# 106          20   Primeira_Liga  2020-07-26  1930                 Moreirense
# 107          31   Primeira_Liga  2020-07-26  1930               Portimonense
# 108          32   Primeira_Liga  2020-07-26  1930            Vitoria Setubal
# 109          34         Serie_A  2020-07-26  2045                   Juventus
# 110          31             MLS  2020-07-27   130                 Toronto FC
# 111          21             MLS  2020-07-27   400       Sporting Kansas City
# 112          33    Championship  2020-07-27  1945                    Cardiff
# 113          34             MLS  2020-07-28   130       San Jose Earthquakes
# 114          35             MLS  2020-07-28   400           Seattle Sounders
# 115           0         Serie_A  2020-07-28  1830                      Parma
# 116           4         Serie_A  2020-07-28  2045             Inter de Milao
# 117           2             MLS  2020-07-29   100              Columbus Crew
# 118           6             MLS  2020-07-29   330           Portland Timbers
# 119           9         Serie_A  2020-07-29  1830                  Sampdoria
# 120          10         Serie_A  2020-07-29  1830                   Sassuolo
# 121          11         Serie_A  2020-07-29  1830              Hellas Verona
# 122           6         Serie_A  2020-07-29  1830                      Lazio
# 123           8         Serie_A  2020-07-29  1830                    Udinese
# 124           9    Championship  2020-07-29  1945               Brentford FC
# 125          13         Serie_A  2020-07-29  2045                 Fiorentina
# 126          10         Serie_A  2020-07-29  2045                     Torino
# 127          12         Serie_A  2020-07-29  2045                   Cagliari
# 128          13    Championship  2020-07-30  1945                     Fulham
# 129          14             MLS  2020-07-31   100         Philadelphia Union
# 130          44     Premiership  2020-08-01  1230                Aberdeen FC
# 131           3     Premiership  2020-08-01  1500                  St Mirren
# 132          43     Premiership  2020-08-01  1500              Dundee United
# 133          16     Premiership  2020-08-01  1500               Hibernian FC
# 134          19     Premiership  2020-08-02  1630                     Celtic
# 135          18     Premiership  2020-08-03  1945                Ross County
# 136          23     Liga_Europa  2020-08-05  1755              FC Copenhagen
# 137          22     Liga_Europa  2020-08-05  1755           Shakhtar Donetsk
# 138          19     Liga_Europa  2020-08-05  2000          Manchester United
# 139          24     Liga_Europa  2020-08-05  2000             Inter de Milao
# 140          36     Liga_Europa  2020-08-06  1755           Bayer Leverkusen
# 141          25     Liga_Europa  2020-08-06  1755                    Sevilha
# 142          28     Liga_Europa  2020-08-06  2000              Wolverhampton
# 143          27     Liga_Europa  2020-08-06  2000                   Basileia
# 144          31       Champions  2020-08-07  2000                   Juventus
# 145          44       Champions  2020-08-07  2000            Manchester City
# 146          58       Champions  2020-08-08  2000             Bayern Munique
# 147          75       Champions  2020-08-08  2000                  Barcelona
# 148          33       Champions  2020-08-12  2000                   Atalanta
# 149          35       Champions  2020-08-13  2000                 RB Leipzig
#
#                          AT   ODDH   ODDD   ODDA ODD_25+ ODD_25-  \
# 0               Southampton   2.40   3.65   2.78    1.63    2.02
# 1              Leeds United   2.98   3.35   2.25    1.65    1.85
# 2         Nottingham Forest   2.62   3.25   2.56    1.78     1.7
# 3                 Leicester   2.46   3.53   3.20    1.95     1.7
# 4                 Barcelona   6.20   4.20   1.47    1.57    2.02
# 5                 Sampdoria   3.00   2.94   2.45    1.80    1.75
# 6                     Eibar   1.70   3.60   4.65    1.55    2.05
# 7                     Betis   2.62   3.25   2.56    1.67    1.88
# 8                    Torino   1.88   3.30   4.10    1.67    1.88
# 9                   Udinese   1.60   4.10   5.85    1.75    1.85
# 10                 US Lecce   1.80   3.55   4.10    1.57    2.04
# 11           Dinamo Moscovo   1.65   3.10   3.95    1.80     1.6
# 12                     Spal   2.30   3.35   2.90    1.61    1.95
# 13              Gil Vicente   2.33   3.25   3.35    2.10    1.55
# 14                 Valencia   1.80   3.85   3.80    1.55    2.05
# 15                  Maiorca   1.80   3.70   3.95    1.63    1.95
# 16              Real Madrid   3.30   3.35   2.10    1.83    1.72
# 17                   Getafe   4.60   3.55   1.72    1.83    1.72
# 18            Celta de Vigo   4.85   3.55   1.70    2.00     1.6
# 19            Real Sociedad   2.17   2.72   4.60    2.37    1.45
# 20          Athletic Bilbao   2.05   3.20   3.60    1.91    1.65
# 21           Inter de Milao   3.05   3.50   2.15    1.45    2.25
# 22                 Maritimo   1.67   4.00   5.25    1.70    1.91
# 23     San Jose Earthquakes   2.45   3.50   2.60    1.50    2.02
# 24   Vancouver Whitecaps FC   1.61   4.00   4.80    1.53     2.0
# 25         New York City FC   3.25   3.50   2.05    1.57     1.9
# 26             Portimonense   3.05   3.05   2.35    1.78    1.75
# 27                Newcastle   1.78   3.45   4.35    1.91    1.65
# 28                  Everton   2.10   3.20   3.45    2.10    1.53
# 29                 SC Braga   5.00   4.05   1.57    1.57    2.02
# 30        Crystal Palace FC   1.50   3.85   6.70    2.12    1.53
# 31                    Lazio   1.60   4.00   4.85    1.55    2.05
# 32               Moreirense   1.33   4.95   7.85    1.57    2.02
# 33          Orlando City SC   2.25   3.35   2.96    1.63    1.83
# 34   New England Revolution   2.12   3.25   3.35    1.67    1.78
# 35          Manchester City   7.90   5.10   1.32     1.4     2.4
# 36                  Bolonha   1.27   5.85   8.00    1.27    2.94
# 37          Vitoria Setubal   1.42   4.25   7.00    1.87    1.67
# 38                  Arsenal   3.10   3.70   2.05    1.65    2.17
# 39                 AC Milao   3.15   3.80   2.00    1.38    2.45
# 40               SL Benfica  20.50   8.00   1.16    1.35    2.67
# 41            Columbus Crew   2.52   3.35   2.60    1.65     1.8
# 42     Washington DC United   2.76   3.40   2.37    1.55    1.95
# 43     Sporting Kansas City   2.86   3.65   2.20    1.42     2.2
# 44      FK Gazovik Orenburg   1.28   3.80   7.10    1.80     1.6
# 45                   Tambov   1.22   4.45   7.35    1.55    1.87
# 46          Spartak Moscovo   2.45   2.86   2.37    1.88    1.55
# 47    Zenit Sao Petersburgo   1.91   3.20   2.90    1.57    1.83
# 48             Arsenal Tula   2.40   2.82   2.45    2.00    1.47
# 49        Lokomotiv Moscovo   3.10   3.30   1.80    1.50    1.95
# 50         FC Akhmat Grozny   1.30   3.85   6.60    1.67    1.72
# 51                 West Ham   1.23   6.00   9.75    1.36    2.52
# 52                  Napoles   5.15   4.05   1.57    1.53     2.1
# 53         Blackburn Rovers   1.72   3.65   4.40    1.60    1.91
# 54                  Preston   2.67   3.10   2.60    1.72    1.75
# 55                Hull City   1.36   4.65   7.85    1.50    2.05
# 56              Barnsley FC   1.31   4.90   9.00    1.53    2.02
# 57               Stoke City   2.11   3.25   3.35    1.87    1.63
# 58            Middlesbrough   2.15   3.10   3.40    1.87    1.63
# 59      Queens Park Rangers   1.21   5.80  12.25    1.47    2.15
# 60                   Fulham   2.52   3.55   2.50    1.57    1.95
# 61                 Charlton   1.60   4.00   4.85    1.50    2.05
# 62             Swansea City   3.60   3.55   1.91    1.57    1.95
# 63             Derby County   2.33   3.35   2.86    1.72    1.75
# 64             Huddersfield   2.25   3.15   3.15    1.78     1.7
# 65                  Chelsea   2.00   3.45   3.45    1.50    2.13
# 66                  AS Roma   6.60   4.80   1.38     1.4     2.4
# 67            Hellas Verona   2.30   3.30   2.92    1.80    1.75
# 68                   Genova   2.35   3.30   2.86    1.80    1.75
# 69               Fiorentina   1.44   4.65   5.95    1.44     2.3
# 70           Brescia Calcio   1.63   4.15   4.45     1.4     2.4
# 71       New York Red Bulls   3.55   3.20   2.05    1.57     1.9
# 72         Minnesota United   3.00   3.60   2.14    1.55    1.95
# 73   Vancouver Whitecaps FC   1.57   3.95   5.15    1.53     2.0
# 74                 Juventus   4.80   3.85   1.63    1.65    1.91
# 75                 Cagliari   1.44   4.70   6.95    1.53     2.2
# 76           Houston Dynamo   1.90   3.75   3.50    1.24    2.82
# 77         Portland Timbers   1.60   3.95   5.05    1.47     2.1
# 78        Vitoria Guimaraes   3.00   3.40   2.20    1.67    1.88
# 79                 Atalanta   2.80   3.95   2.13    1.31    2.72
# 80           Pacos Ferreira   2.37   3.15   2.92    2.05    1.55
# 81                    Parma   3.30   3.60   2.00    1.53    2.12
# 82           Inter de Milao   4.70   3.95   1.63    1.47     2.2
# 83                  Rio Ave   3.90   3.70   1.80    1.70    1.85
# 84                Famalicao   3.65   3.40   1.95    1.83    1.72
# 85                 Sassuolo   1.53   4.33   5.05    1.42    2.35
# 86                 FC Porto   2.58   3.50   2.45    1.55    2.05
# 87              Sporting CP   1.79   4.21   4.89    1.67    1.95
# 88          Montreal Impact   1.88   3.65   3.65    None    None
# 89   New England Revolution   2.50   3.45   2.56    None    None
# 90                Tottenham   4.10   3.50   1.83    1.83    1.72
# 91        Manchester United   3.10   3.30   2.20    1.75     1.8
# 92            Wolverhampton   1.80   3.60   4.05    1.75    1.78
# 93                  Watford   1.87   3.75   3.60    1.53     2.1
# 94         Sheffield United   2.10   3.40   3.25    1.72    1.83
# 95             Norwich City   1.05  11.00  27.00    1.14     3.9
# 96              Bournemouth   2.17   3.60   2.94    1.50    2.16
# 97                 Brighton   2.20   3.40   3.00    1.75     1.8
# 98                Liverpool   6.35   4.60   1.42    1.42    2.33
# 99              Aston Villa   2.76   3.40   2.37    1.61    1.95
# 100                US Lecce   2.05   3.65   3.15    1.47     2.2
# 101                 Udinese   3.25   3.30   2.14    1.75     1.8
# 102            Brentford FC   3.15   3.25   2.20    None    None
# 103                   Lazio   3.35   3.40   2.05    1.55    2.05
# 104                  Torino   5.00   3.90   1.60    1.53     2.1
# 105              Fiorentina   1.53   4.35   5.05    1.42    2.33
# 106                 Tondela   2.90   3.15   2.40    1.95    1.61
# 107              Desp. Aves   1.14   6.45  20.00    1.63    1.95
# 108          Belenenses SAD   1.57   3.75   5.55    1.75     1.8
# 109               Sampdoria   1.26   5.80   9.00    1.44     2.3
# 110        New York City FC   2.13   3.65   2.98    None    None
# 111  Vancouver Whitecaps FC   1.40   4.70   6.55    None    None
# 112                  Fulham   2.68   3.00   2.66    None    None
# 113          Real Salt Lake   2.00   3.70   3.25    None    None
# 114          Los Angeles FC   3.15   3.90   2.00    None    None
# 115                Atalanta   6.25   5.20   1.47    1.35    2.72
# 116                 Napoles   2.00   3.55   3.35    1.63    1.95
# 117        Minnesota United   2.00   3.45   3.45    None    None
# 118           FC Cincinnati   1.75   3.80   4.05    None    None
# 119                AC Milao   4.90   3.90   1.61    1.55    2.05
# 120                  Genova   2.25   3.50   2.82    1.50    2.16
# 121                    Spal   1.50   4.30   5.35    1.55    2.05
# 122          Brescia Calcio   1.17   7.35  11.50    1.22     3.2
# 123                US Lecce   2.18   3.55   2.94    1.50    2.14
# 124            Swansea City   1.55   4.00   5.45    None    None
# 125                 Bolonha   2.00   3.55   3.35    1.57    2.02
# 126                 AS Roma   4.55   4.15   1.61    1.45    2.25
# 127                Juventus   5.30   4.00   1.55    1.55    2.05
# 128                 Cardiff   2.00   3.35   3.55    None    None
# 129    Sporting Kansas City   3.05   3.75   2.05    None    None
# 130                 Rangers   6.55   4.45   1.42    1.57    1.95
# 131           Livingston FC   2.54   3.20   2.68    2.02    1.53
# 132         FC St Johnstone   2.68   3.20   2.54    2.02    1.53
# 133           Kilmarnock FC   2.05   3.35   3.35    1.85    1.65
# 134     Hamilton Academical   1.09   9.00  20.50    1.28    2.67
# 135           Motherwell FC   2.92   3.40   2.25    1.80    1.67
# 136     Istanbul Basaksehir   2.20   3.20   3.15    None    None
# 137              Wolfsburgo   2.40   3.40   2.70    None    None
# 138                    Linz   1.28   5.35   8.50    None    None
# 139                  Getafe   1.95   3.30   3.80    None    None
# 140                 Rangers   1.65   3.90   4.55    None    None
# 141                 AS Roma   2.15   3.20   3.30    None    None
# 142              Olympiacos   1.80   3.35   4.45    None    None
# 143     Eintracht Frankfurt   2.50   3.40   2.58    None    None
# 144                    Lyon   1.40   4.40   7.15    None    None
# 145             Real Madrid   1.63   4.25   4.33    None    None
# 146                 Chelsea   1.55   4.25   5.10    None    None
# 147                 Napoles   1.60   3.75   5.35    None    None
# 148                     PSG   2.76   3.65   2.25    None    None
# 149      Atletico de Madrid   3.25   3.15   2.20    None    None
#
#     ODD_BthScore_Yes ODD_BthScore_No ODD_1X ODD_12 ODD_X2 Scrape_Date  \
# 0               1.50            2.16   1.40   1.23   1.53  2020-07-19
# 1               1.50            2.05   1.57   1.24   1.35  2020-07-19
# 2               1.61             1.9   1.45   1.25   1.44  2020-07-19
# 3               1.67            1.87   1.35   1.27   1.53  2020-07-19
# 4               1.67            1.87   2.52   1.16   1.08  2020-07-19
# 5               1.57            2.02   1.47   1.32   1.33  2020-07-19
# 6               1.53            2.12   1.15   1.22   2.02  2020-07-19
# 7               1.53             2.1   1.45   1.26   1.44  2020-07-19
# 8               1.57            2.04   1.20   1.26    1.8  2020-07-19
# 9               1.75             1.8   1.12   1.19   2.25  2020-07-19
# 10              1.50            2.13   1.19   1.22   1.91  2020-07-19
# 11              1.72            1.67   1.15   1.22   1.95  2020-07-19
# 12              1.47             2.2   1.36   1.25   1.55  2020-07-19
# 13              1.83            1.72   1.30   1.28   1.57  2020-07-19
# 14              1.53             2.1   1.22   1.19   1.91  2020-07-19
# 15              1.57            2.02   1.21   1.21   1.88  2020-07-19
# 16              1.65             1.9   1.67   1.25   1.28  2020-07-19
# 17              1.75             1.8   2.00   1.23   1.16  2020-07-19
# 18              1.91            1.65   2.04   1.23   1.14  2020-07-19
# 19              1.91            1.65   1.18   1.38   1.65  2020-07-19
# 20              1.72            1.83   1.25   1.27   1.67  2020-07-19
# 21              1.38            2.45   1.63   1.23   1.33  2020-07-19
# 22              1.65             1.9   1.14    1.2   2.11  2020-07-19
# 23              1.42            2.19   1.44   1.22    1.5  2020-07-19
# 24              1.55            1.95   1.15   1.16   2.18  2020-07-19
# 25              1.50            2.05   1.67   1.21    1.3  2020-07-19
# 26              1.57            2.02   1.53    1.3   1.32  2020-07-19
# 27              1.80            1.75   1.18   1.23   1.91  2020-07-19
# 28              1.85             1.7   1.27   1.27   1.65  2020-07-19
# 29              1.63            1.95   2.25   1.17   1.14  2020-07-19
# 30              2.25            1.45   1.07   1.19   2.45  2020-07-19
# 31              1.60             2.0   1.14   1.18   2.19  2020-07-19
# 32              1.87            1.67   1.04   1.11    3.0  2020-07-19
# 33              1.50            2.02   1.35   1.23   1.57  2020-07-19
# 34              1.55            1.95   1.28   1.25   1.63  2020-07-19
# 35              1.63            1.95   3.10    1.1   1.04  2020-07-19
# 36              1.53             2.1   1.04   1.08    3.4  2020-07-19
# 37              2.05            1.55   1.06   1.16   2.63  2020-07-19
# 38              1.50            2.16   1.67   1.21   1.32  2020-07-19
# 39              1.35            2.56   1.72    1.2    1.3  2020-07-19
# 40              2.00             1.6   5.00   1.07      -  2020-07-21
# 41              1.50            2.02   1.44   1.23   1.45  2020-07-19
# 42              1.44            2.16   1.53   1.23   1.38  2020-07-21
# 43              1.35            2.37   1.57   1.21   1.38  2020-07-19
# 44              2.14             1.4   1.03   1.17   2.92  2020-07-19
# 45              1.95             1.5   1.02   1.13   3.30  2020-07-21
# 46              1.67            1.72   1.42   1.26   1.40  2020-07-21
# 47              1.50            1.95   1.30    1.2   1.67  2020-07-21
# 48              1.75            1.65   1.40   1.27   1.42  2020-07-22
# 49              1.45            2.04   1.75    1.2   1.25  2020-07-22
# 50              1.95             1.5   1.03   1.17   2.86  2020-07-22
# 51              1.75            1.78   1.03   1.11   3.70  2020-07-21
# 52              1.57            2.02   2.25   1.17   1.13  2020-07-19
# 53              1.55             2.0   1.17    1.2   1.95  2020-07-19
# 54              1.53             2.0   1.44   1.27   1.42  2020-07-19
# 55              1.72            1.75   1.04   1.12   2.92  2020-07-19
# 56              1.80            1.67   1.03   1.14   3.15  2020-07-19
# 57              1.67             1.8   1.27   1.25   1.65  2020-07-19
# 58              1.65            1.83   1.27   1.27   1.63  2020-07-19
# 59              1.95            1.57   1.02    1.1    3.9  2020-07-19
# 60              1.47            2.12   1.47   1.21   1.47  2020-07-21
# 61              1.55             2.0   1.14   1.16    2.2  2020-07-22
# 62              1.47             2.1   1.78   1.21   1.25  2020-07-22
# 63              1.57            1.95   1.36   1.23   1.53  2020-07-22
# 64              1.60            1.91   1.31   1.26   1.57  2020-07-22
# 65              1.44             2.3   1.27   1.23   1.72  2020-07-19
# 66              1.55            2.05   2.78   1.12   1.07  2020-07-19
# 67              1.63            1.95   1.36   1.25   1.55  2020-07-19
# 68              1.63            1.95   1.36   1.26   1.53  2020-07-19
# 69              1.60             2.0   1.10   1.13   2.60  2020-07-21
# 70              1.42            2.33   1.17   1.16   2.14  2020-07-22
# 71              1.47             2.1   1.70   1.25   1.25  2020-07-22
# 72              1.45            2.11   1.63   1.21   1.33  2020-07-22
# 73              1.55            1.95   1.13   1.17   2.25  2020-07-21
# 74              1.63            1.95   2.13   1.19   1.14  2020-07-19
# 75              1.65            1.91   1.08   1.14   2.65  2020-07-23
# 76              1.23             2.9   1.26   1.19    1.8  2020-07-19
# 77              1.50            2.02   1.14   1.17    2.2  2020-07-19
# 78              1.55            2.05   1.60   1.24   1.33  2020-07-22
# 79              1.30            2.76   1.63   1.18   1.38  2020-07-23
# 80              1.80            1.75   1.36   1.28    1.5  2020-07-22
# 81              1.45            2.25   1.72   1.22   1.28  2020-07-23
# 82              1.50            2.16   2.15   1.18   1.15  2020-07-24
# 83              1.65            1.91   1.88   1.21   1.21  2020-07-22
# 84              1.67            1.87   1.72   1.25   1.25  2020-07-22
# 85              1.50            2.18   1.13   1.16   2.33  2020-07-24
# 86              1.47             2.2   1.47   1.23   1.44  2020-07-22
# 87              1.63            1.95   1.18    1.2   2.02  2020-07-25
# 88              None            None   None   None   None  2020-07-24
# 89              None            None   None   None   None  2020-07-24
# 90              1.72            1.83   1.88   1.23   1.20  2020-07-21
# 91              1.57            2.02   1.57   1.26   1.32  2020-07-23
# 92              1.67            1.87   1.20   1.22    1.9  2020-07-24
# 93              1.50            2.17   1.25    1.2   1.83  2020-07-25
# 94              1.60             2.0   1.30   1.24   1.65  2020-07-25
# 95              2.20            1.47      -   1.02    8.0  2020-07-25
# 96              1.42            2.33   1.35   1.22   1.61  2020-07-25
# 97              1.61            1.95   1.33   1.24   1.57  2020-07-25
# 98              1.57            2.02   2.64   1.14   1.08  2020-07-26
# 99              1.50            2.18   1.53   1.24   1.38  2020-07-26
# 100             1.42            2.35   1.31   1.21   1.67  2020-07-23
# 101             1.60             2.0   1.63   1.26    1.3  2020-07-23
# 102             None            None   None   None   None  2020-07-23
# 103             1.47             2.2   1.70   1.24   1.28  2020-07-24
# 104             1.57            2.04   2.20   1.18   1.14  2020-07-26
# 105             1.50            2.14   1.13   1.15   2.33  2020-07-26
# 106             1.75             1.8   1.50   1.28   1.36  2020-07-22
# 107             None            None   None   None   None  2020-07-23
# 108             1.75            1.78   1.11    1.2    2.2  2020-07-23
# 109             1.83            1.72   1.03   1.12    3.5  2020-07-23
# 110             None            None   None   None   None  2020-07-24
# 111             None            None   None   None   None  2020-07-26
# 112             None            None   None   None   None  2020-07-24
# 113             None            None   None   None   None  2020-07-24
# 114             None            None   None   None   None  2020-07-24
# 115             1.47             2.2   2.58   1.12   1.11  2020-07-28
# 116             1.53            2.11   1.28   1.23   1.72  2020-07-27
# 117             None            None   None   None   None  2020-07-28
# 118             None            None   None   None   None  2020-07-27
# 119             1.57            2.04   2.16   1.19   1.14  2020-07-27
# 120             1.42            2.37   1.38   1.23   1.55  2020-07-27
# 121             1.65            1.91   1.12   1.16   2.37  2020-07-27
# 122             1.67            1.88   1.02   1.08   4.45  2020-07-28
# 123             1.44             2.3   1.35   1.22   1.61  2020-07-28
# 124             None            None   None   None   None  2020-07-28
# 125             1.50            2.16   1.28   1.22   1.72  2020-07-27
# 126             1.50            2.19   2.16   1.17   1.17  2020-07-28
# 127             1.60             2.0   2.25   1.17   1.12  2020-07-28
# 128             None            None   None   None   None  2020-07-28
# 129             None            None   None   None   None  2020-07-28
# 130             1.75            1.72   2.65   1.13   1.07  2020-07-21
# 131             1.75            1.72   1.40   1.26   1.45  2020-07-21
# 132             1.75            1.72   1.45   1.25   1.40  2020-07-21
# 133             1.67             1.8   1.28   1.24   1.67  2020-07-28
# 134             2.20            1.44      -   1.04    6.2  2020-07-28
# 135             1.65            1.85   1.55   1.23   1.36  2020-07-21
# 136             None            None   None   None   None  2020-07-19
# 137             None            None   None   None   None  2020-07-28
# 138             None            None   None   None   None  2020-07-22
# 139             None            None   None   None   None  2020-07-27
# 140             None            None   None   None   None  2020-07-21
# 141             None            None   None   None   None  2020-07-28
# 142             None            None   None   None   None  2020-07-27
# 143             None            None   None   None   None  2020-07-28
# 144             None            None   None   None   None  2020-07-19
# 145             None            None   None   None   None  2020-07-19
# 146             None            None   None   None   None  2020-07-19
# 147             None            None   None   None   None  2020-07-19
# 148             None            None   None   None   None  2020-07-28
# 149             None            None   None   None   None  2020-07-27
#
#      Scrape_Time
# 0           1145
# 1           1145
# 2           1145
# 3           1145
# 4           1145
# 5           1145
# 6           1145
# 7           1145
# 8           1145
# 9           1145
# 10          1145
# 11          1145
# 12          1145
# 13          1145
# 14          1145
# 15          1145
# 16          1145
# 17          1145
# 18          1145
# 19          1145
# 20          1145
# 21          1145
# 22          1145
# 23          1145
# 24          1145
# 25          1145
# 26          1145
# 27          1145
# 28          1145
# 29          1145
# 30          1145
# 31          1145
# 32          1145
# 33          1145
# 34          1145
# 35          1145
# 36          1145
# 37          1145
# 38          1145
# 39          1145
# 40          1357
# 41          1145
# 42          1358
# 43          1145
# 44          1145
# 45          1354
# 46          1354
# 47          1354
# 48          1450
# 49          1450
# 50          1450
# 51          1401
# 52          1145
# 53          1145
# 54          1145
# 55          1145
# 56          1145
# 57          1145
# 58          1145
# 59          1145
# 60          1351
# 61          1448
# 62          1448
# 63          1448
# 64          1448
# 65          1145
# 66          1145
# 67          1145
# 68          1145
# 69          1359
# 70          1456
# 71          1455
# 72          1455
# 73          1358
# 74          1145
# 75          1331
# 76          1145
# 77          1145
# 78          1454
# 79          1331
# 80          1454
# 81          1331
# 82          1529
# 83          1454
# 84          1454
# 85          1529
# 86          1454
# 87          2001
# 88          1528
# 89          1528
# 90          1401
# 91          1332
# 92          1531
# 93          2003
# 94          2003
# 95          2003
# 96          2003
# 97          2003
# 98          1217
# 99          1217
# 100         1331
# 101         1331
# 102         1325
# 103         1529
# 104         1216
# 105         1216
# 106         1454
# 107         1329
# 108         1329
# 109         1331
# 110         1528
# 111         1215
# 112         1522
# 113         1528
# 114         1528
# 115         1511
# 116         1639
# 117         1510
# 118         1639
# 119         1639
# 120         1639
# 121         1639
# 122         1511
# 123         1511
# 124         1506
# 125         1639
# 126         1511
# 127         1511
# 128         1506
# 129         1510
# 130         1353
# 131         1353
# 132         1353
# 133         1507
# 134         1507
# 135         1353
# 136         1145
# 137         1508
# 138         1451
# 139         1636
# 140         1355
# 141         1508
# 142         1636
# 143         1508
# 144         1145
# 145         1145
# 146         1145
# 147         1145
# 148         1509
# 149         1637

# %%
df0 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano0.csv')
df1 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano1.csv')
df2 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano2.csv')
df3 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano3.csv')
df4 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano4.csv')
df5 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano5.csv')
df6 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano6.csv')
df7 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano7.csv')
df8 = pd.read_csv('C://Users//joaom//Documents//Projetos//PYTHON//Apostas//AAPredictions//BetanoOdds//Filtered_Data//Betano8.csv')

# %%
Betano_odd([df0,df1,df2,df3,df4,df5,df6,df7,df8])
# Out:
#              League                         HT                      AT  \
# 0    Premier_League                Bournemouth             Southampton
# 1      Championship               Derby County            Leeds United
# 2      Championship                Barnsley FC       Nottingham Forest
# 3    Premier_League                  Tottenham               Leicester
# 4           La_Liga                     Alaves               Barcelona
# 5           Serie_A                      Parma               Sampdoria
# 6           La_Liga                 Villarreal                   Eibar
# 7           La_Liga            Real Valladolid                   Betis
# 8           Serie_A                 Fiorentina                  Torino
# 9           Serie_A                    Napoles                 Udinese
# 10          Serie_A                     Genova                US Lecce
# 11             RFPL                  Krasnodar          Dinamo Moscovo
# 12          Serie_A             Brescia Calcio                    Spal
# 13    Primeira_Liga             Belenenses SAD             Gil Vicente
# 14          La_Liga                    Sevilha                Valencia
# 15          La_Liga                 CA Osasuna                 Maiorca
# 16          La_Liga                    Leganes             Real Madrid
# 17          La_Liga                    Levante                  Getafe
# 18          La_Liga                   Espanhol           Celta de Vigo
# 19          La_Liga         Atletico de Madrid           Real Sociedad
# 20          La_Liga                 Granada CF         Athletic Bilbao
# 21          Serie_A                    AS Roma          Inter de Milao
# 22    Primeira_Liga          Vitoria Guimaraes                Maritimo
# 23              MLS               Chicago Fire    San Jose Earthquakes
# 24              MLS           Seattle Sounders  Vancouver Whitecaps FC
# 25              MLS             Inter Miami CF        New York City FC
# 26    Primeira_Liga             Pacos Ferreira            Portimonense
# 27   Premier_League                   Brighton               Newcastle
# 28   Premier_League           Sheffield United                 Everton
# 29    Primeira_Liga                    Tondela                SC Braga
# 30   Premier_League              Wolverhampton       Crystal Palace FC
# 31          Serie_A                   Juventus                   Lazio
# 32    Primeira_Liga                   FC Porto              Moreirense
# 33              MLS         Philadelphia Union         Orlando City SC
# 34              MLS                 Toronto FC  New England Revolution
# 35   Premier_League                    Watford         Manchester City
# 36          Serie_A                   Atalanta                 Bolonha
# 37    Primeira_Liga                Sporting CP         Vitoria Setubal
# 38   Premier_League                Aston Villa                 Arsenal
# 39          Serie_A                   Sassuolo                AC Milao
# 40    Primeira_Liga                 Desp. Aves              SL Benfica
# 41              MLS             Atlanta United           Columbus Crew
# 42              MLS            Montreal Impact    Washington DC United
# 43              MLS             Real Salt Lake    Sporting Kansas City
# 44             RFPL                     Rostov   Zenit Sao Petersburgo
# 45             RFPL                Rubin Kazan         Spartak Moscovo
# 46             RFPL               CSKA Moscovo                  Tambov
# 47             RFPL  Ural Sverdlovskaya Oblast       Lokomotiv Moscovo
# 48             RFPL             Dinamo Moscovo     FK Gazovik Orenburg
# 49             RFPL                  Krasnodar        FC Akhmat Grozny
# 50             RFPL                     FC Ufa            Arsenal Tula
# 51   Premier_League          Manchester United                West Ham
# 52          Serie_A                      Parma                 Napoles
# 53     Championship                 Luton Town        Blackburn Rovers
# 54     Championship                Millwall FC            Huddersfield
# 55     Championship               Bristol City                 Preston
# 56     Championship                      Wigan                  Fulham
# 57     Championship                    Cardiff               Hull City
# 58     Championship               Leeds United                Charlton
# 59     Championship                    Reading            Swansea City
# 60     Championship                 Birmingham            Derby County
# 61     Championship               Brentford FC             Barnsley FC
# 62     Championship          Nottingham Forest              Stoke City
# 63     Championship        Sheffield Wednesday           Middlesbrough
# 64     Championship                  West Brom     Queens Park Rangers
# 65   Premier_League                  Liverpool                 Chelsea
# 66          Serie_A                   US Lecce          Brescia Calcio
# 67          Serie_A             Inter de Milao              Fiorentina
# 68          Serie_A                       Spal                 AS Roma
# 69          Serie_A                     Torino           Hellas Verona
# 70          Serie_A                  Sampdoria                  Genova
# 71              MLS              FC Cincinnati      New York Red Bulls
# 72              MLS            Colorado Rapids        Minnesota United
# 73              MLS               Chicago Fire  Vancouver Whitecaps FC
# 74          Serie_A                    Udinese                Juventus
# 75          Serie_A                      Lazio                Cagliari
# 76              MLS         Los Angeles Galaxy          Houston Dynamo
# 77              MLS             Los Angeles FC        Portland Timbers
# 78    Primeira_Liga                Santa Clara       Vitoria Guimaraes
# 79          Serie_A                   AC Milao                Atalanta
# 80    Primeira_Liga                Gil Vicente          Pacos Ferreira
# 81          Serie_A             Brescia Calcio                   Parma
# 82          Serie_A                     Genova          Inter de Milao
# 83    Primeira_Liga                   Boavista                 Rio Ave
# 84    Primeira_Liga                   Maritimo               Famalicao
# 85          Serie_A                    Napoles                Sassuolo
# 86    Primeira_Liga                 SL Benfica             Sporting CP
# 87    Primeira_Liga                   SC Braga                FC Porto
# 88              MLS            Orlando City SC         Montreal Impact
# 89              MLS         Philadelphia Union  New England Revolution
# 90   Premier_League                  Newcastle               Liverpool
# 91   Premier_League            Manchester City            Norwich City
# 92   Premier_League                  Leicester       Manchester United
# 93   Premier_League          Crystal Palace FC               Tottenham
# 94   Premier_League                    Burnley                Brighton
# 95   Premier_League                Southampton        Sheffield United
# 96   Premier_League                    Everton             Bournemouth
# 97   Premier_League                    Arsenal                 Watford
# 98   Premier_League                   West Ham             Aston Villa
# 99   Premier_League                    Chelsea           Wolverhampton
# 100         Serie_A                    Bolonha                US Lecce
# 101         Serie_A              Hellas Verona                   Lazio
# 102         Serie_A                   Cagliari                 Udinese
# 103         Serie_A                    AS Roma              Fiorentina
# 104         Serie_A                       Spal                  Torino
# 105    Championship               Swansea City            Brentford FC
# 106   Primeira_Liga                 Moreirense                 Tondela
# 107   Primeira_Liga               Portimonense              Desp. Aves
# 108   Primeira_Liga            Vitoria Setubal          Belenenses SAD
# 109         Serie_A                   Juventus               Sampdoria
# 110             MLS                 Toronto FC        New York City FC
# 111             MLS       Sporting Kansas City  Vancouver Whitecaps FC
# 112    Championship                    Cardiff                  Fulham
# 113             MLS       San Jose Earthquakes          Real Salt Lake
# 114             MLS           Seattle Sounders          Los Angeles FC
# 115         Serie_A                      Parma                Atalanta
# 116         Serie_A             Inter de Milao                 Napoles
# 117             MLS              Columbus Crew        Minnesota United
# 118             MLS           Portland Timbers           FC Cincinnati
# 119         Serie_A                    Udinese                US Lecce
# 120         Serie_A                      Lazio          Brescia Calcio
# 121         Serie_A                  Sampdoria                AC Milao
# 122         Serie_A                   Sassuolo                  Genova
# 123         Serie_A              Hellas Verona                    Spal
# 124    Championship               Brentford FC            Swansea City
# 125         Serie_A                 Fiorentina                 Bolonha
# 126         Serie_A                   Cagliari                Juventus
# 127         Serie_A                     Torino                 AS Roma
# 128    Championship                     Fulham                 Cardiff
# 129             MLS         Philadelphia Union    Sporting Kansas City
# 130     Premiership                Aberdeen FC                 Rangers
# 131     Premiership                  St Mirren           Livingston FC
# 132     Premiership              Dundee United         FC St Johnstone
# 133     Premiership               Hibernian FC           Kilmarnock FC
# 134     Premiership                     Celtic     Hamilton Academical
# 135     Premiership                Ross County           Motherwell FC
# 136     Liga_Europa              FC Copenhagen     Istanbul Basaksehir
# 137     Liga_Europa           Shakhtar Donetsk              Wolfsburgo
# 138     Liga_Europa             Inter de Milao                  Getafe
# 139     Liga_Europa          Manchester United                    Linz
# 140     Liga_Europa           Bayer Leverkusen                 Rangers
# 141     Liga_Europa                    Sevilha                 AS Roma
# 142     Liga_Europa              Wolverhampton              Olympiacos
# 143     Liga_Europa                   Basileia     Eintracht Frankfurt
# 144       Champions                   Juventus                    Lyon
# 145       Champions            Manchester City             Real Madrid
# 146       Champions             Bayern Munique                 Chelsea
# 147       Champions                  Barcelona                 Napoles
# 148       Champions                   Atalanta                     PSG
# 149       Champions                 RB Leipzig      Atletico de Madrid
#
#            Date  Time  ODDH_TOP1  Time_1 ODDH_TOP2 Time_2 ODDH_TOP3 Time_3
# 0    2020-07-19  1400       2.40       2      None   None      None   None
# 1    2020-07-19  1400       2.98       2      None   None      None   None
# 2    2020-07-19  1500       2.62       3      None   None      None   None
# 3    2020-07-19  1600       2.46       4      None   None      None   None
# 4    2020-07-19  1600       6.20       4      None   None      None   None
# 5    2020-07-19  1615       3.00       4      None   None      None   None
# 6    2020-07-19  1730       1.70       5      None   None      None   None
# 7    2020-07-19  1730       2.62       5      None   None      None   None
# 8    2020-07-19  1830       1.88       6      None   None      None   None
# 9    2020-07-19  1830       1.60       6      None   None      None   None
# 10   2020-07-19  1830       1.80       6      None   None      None   None
# 11   2020-07-19  1830       1.65       6      None   None      None   None
# 12   2020-07-19  1830       2.30       6      None   None      None   None
# 13   2020-07-19  1900       2.33       7      None   None      None   None
# 14   2020-07-19  2000       1.80       8      None   None      None   None
# 15   2020-07-19  2000       1.80       8      None   None      None   None
# 16   2020-07-19  2000       3.30       8      None   None      None   None
# 17   2020-07-19  2000       4.60       8      None   None      None   None
# 18   2020-07-19  2000       4.85       8      None   None      None   None
# 19   2020-07-19  2000       2.17       8      None   None      None   None
# 20   2020-07-19  2000       2.05       8      None   None      None   None
# 21   2020-07-19  2045       3.05       9      None   None      None   None
# 22   2020-07-19  2115       1.67       9      None   None      None   None
# 23   2020-07-20   100       2.45      22      None   None      None   None
# 24   2020-07-20   330       1.61      45      None   None      None   None
# 25   2020-07-20  1400       3.25      26      None   None      None   None
# 26   2020-07-20  1700       3.05      29      None   None      None   None
# 27   2020-07-20  1800       1.78      30      None   None      None   None
# 28   2020-07-20  1800       2.10      30      None   None      None   None
# 29   2020-07-20  1915       5.00      31      None   None      None   None
# 30   2020-07-20  2015       1.50      32      None   None      None   None
# 31   2020-07-20  2045       1.60      33      None   None      None   None
# 32   2020-07-20  2115       1.33      33      None   None      None   None
# 33   2020-07-21   100       2.25      46      None   None      None   None
# 34   2020-07-21  1400       2.12      50      None   None      None   None
# 35   2020-07-21  1800       8.00       3       7.9     54      None   None
# 36   2020-07-21  1830       1.30       4      1.27     54      None   None
# 37   2020-07-21  1900       1.45       5      1.42     55      None   None
# 38   2020-07-21  2015       3.50       6       3.1     56      None   None
# 39   2020-07-21  2045       3.75       6      3.15     57      None   None
# 40   2020-07-21  2115      20.50       7      None   None      None   None
# 41   2020-07-22   100       2.82      20      2.52     70      None   None
# 42   2020-07-22   330       2.76      43      None   None      None   None
# 43   2020-07-22  1400       3.00      24      2.86     74      None   None
# 44   2020-07-22  1700       2.19      77      2.17      2      1.91     27
# 45   2020-07-22  1700       2.68      77      2.68      2      2.45     27
# 46   2020-07-22  1700       1.28      77      1.26      2      1.22     27
# 47   2020-07-22  1700       5.40      77       3.7     27       3.1      2
# 48   2020-07-22  1700       1.53       2      1.42     27      1.28     77
# 49   2020-07-22  1700       1.40      27       1.3      2      None   None
# 50   2020-07-22  1700       2.45      27       2.4      2      None   None
# 51   2020-07-22  1800       1.27       3      1.26     78      1.23     27
# 52   2020-07-22  1830       7.10       3       5.3     28      5.15     78
# 53   2020-07-22  1930       1.88       4      1.78     29      1.72     79
# 54   2020-07-22  1930       2.33      79      2.33     29      2.25      4
# 55   2020-07-22  1930       2.84       4      2.72     29      2.67     79
# 56   2020-07-22  1930       2.70       4      2.67     79      2.52     29
# 57   2020-07-22  1930       1.42       4       1.4     29      1.36     79
# 58   2020-07-22  1930       1.65      79      1.65     29       1.6      4
# 59   2020-07-22  1930       3.85      79      3.65     29       3.6      4
# 60   2020-07-22  1930       2.80      79      2.62     29      2.33      4
# 61   2020-07-22  1930       1.42       4      1.38     29      1.31     79
# 62   2020-07-22  1930       2.14      29      2.14      4      2.11     79
# 63   2020-07-22  1930       2.37       4       2.3     29      2.15     79
# 64   2020-07-22  1930       1.26       4      1.25     29      1.21     79
# 65   2020-07-22  2015       2.07       5         2     80         2     30
# 66   2020-07-22  2045       1.83      81      1.75     30      1.63      5
# 67   2020-07-22  2045       1.53      81       1.5      5      1.44     30
# 68   2020-07-22  2045       9.00       5         8     30       6.6     81
# 69   2020-07-22  2045       2.45       5       2.3     81       2.3     30
# 70   2020-07-22  2045       2.40      30       2.4      5      2.35     81
# 71   2020-07-23   100       4.00      94      3.75     44      3.55     19
# 72   2020-07-23   330       3.05     117      3.05     67         3     42
# 73   2020-07-23  1400       1.61      23      1.61      0      1.57     48
# 74   2020-07-23  1830       5.60       4      5.25     27      4.95     52
# 75   2020-07-23  2045       1.47     105      1.47     54      1.47     29
# 76   2020-07-24   100       2.54      20       2.5     68       2.5     43
# 77   2020-07-24   330       1.61      43       1.6    141       1.6     91
# 78   2020-07-24  1900       3.10       3         3     52         3     29
# 79   2020-07-24  2045       2.86       5       2.8     31      None   None
# 80   2020-07-24  2115       2.58       5      2.37     54      2.37     31
# 81   2020-07-25  1615       3.30      50      None   None      None   None
# 82   2020-07-25  1830       4.75      52       4.7     27      None   None
# 83   2020-07-25  1900       4.35      27       4.3     53       3.9     76
# 84   2020-07-25  1900       3.90      53      3.65     76      3.65     27
# 85   2020-07-25  2045       1.61       0      1.55     55      1.53     29
# 86   2020-07-25  2115       1.91      78       1.9     55       1.9     29
# 87   2020-07-25  2115       2.67      29      2.63     55      2.63      1
# 88   2020-07-26   100       2.04      13      1.88     42      None   None
# 89   2020-07-26   330       2.76      36       2.5     65      None   None
# 90   2020-07-26  1600       7.90      74      7.15     48      6.95    121
# 91   2020-07-26  1600       1.12     121      1.07     97      1.07     74
# 92   2020-07-26  1600       3.49       3       3.3    121       3.2     19
# 93   2020-07-26  1600       6.50       3       5.8     74       5.8     48
# 94   2020-07-26  1600       2.45       3      2.33     97      2.25    121
# 95   2020-07-26  1600       2.52     121      2.16     97      2.16     74
# 96   2020-07-26  1600       2.35       3       2.2     97       2.2     74
# 97   2020-07-26  1600       2.20       3      1.95     74      1.91     97
# 98   2020-07-26  1600       3.05      74         3     48      2.98     97
# 99   2020-07-26  1600       1.88      97      1.87      3      1.85     74
# 100  2020-07-26  1615       2.37      48       2.3     20      2.16      3
# 101  2020-07-26  1830       3.40      76      3.35     51      3.35     22
# 102  2020-07-26  1830       3.55      51      3.55     22       3.5      6
# 103  2020-07-26  1830       1.63      51      1.61     76      1.61     22
# 104  2020-07-26  1830       5.40      76      5.35     51       5.2     22
# 105  2020-07-26  1830       3.75      22       3.7      6      3.65     51
# 106  2020-07-26  1930       3.15      78      3.15     52       3.1     23
# 107  2020-07-26  1930       1.17     100      1.16      7      1.15     52
# 108  2020-07-26  1930       1.67     100      1.65      7      1.61     52
# 109  2020-07-26  2045       1.32       8      1.27     24      1.26     79
# 110  2020-07-27   130       2.13      69      2.13     40      2.13     24
# 111  2020-07-27   400       1.50      96      1.45     67       1.4     51
# 112  2020-07-27  1945       2.96       3      2.72    102      2.72     47
# 113  2020-07-28   130       2.10      20         2     93         2     64
# 114  2020-07-28   400       3.50      47       3.2     91       3.2     75
# 115  2020-07-28  1830       6.85      25      6.25      3      None   None
# 116  2020-07-28  2045       2.13       5         2     28      None   None
# 117  2020-07-29   100       2.25     114       2.2     85      2.05     69
# 118  2020-07-29   330       1.83     137      1.78    108      1.78     92
# 119  2020-07-29  1830       2.20      49      2.18     27      None   None
# 120  2020-07-29  1830       1.19      49      1.17     27      None   None
# 121  2020-07-29  1830       5.05      27       4.9     49      None   None
# 122  2020-07-29  1830       2.25      49      2.25     27      None   None
# 123  2020-07-29  1830       1.50      49       1.5     27      None   None
# 124  2020-07-29  1945       1.61      51      1.55     28      None   None
# 125  2020-07-29  2045       2.00      52         2     29      None   None
# 126  2020-07-29  2045       5.75      52       5.3     29      None   None
# 127  2020-07-29  2045       4.60      52      4.55     29      None   None
# 128  2020-07-30  1945       2.00      52      None   None      None   None
# 129  2020-07-31   100       3.05      66      None   None      None   None
# 130  2020-08-01  1230       7.10     317      6.65     93      6.55    262
# 131  2020-08-01  1500       2.90      95       2.8    118      2.58    315
# 132  2020-08-01  1500       2.74     315      2.74    118      2.72     95
# 133  2020-08-01  1500       2.13     315      2.12    118       2.1    265
# 134  2020-08-02  1630       1.12     340      1.11    290      1.11    265
# 135  2020-08-03  1945       3.00     368         3    148      2.96    171
# 136  2020-08-05  1755       2.20     414       2.2    364       2.2    339
# 137  2020-08-05  1755       2.56     414      2.56    364      2.56    339
# 138  2020-08-05  2000       2.00     416         2    366         2    341
# 139  2020-08-05  2000       1.30     416       1.3    366      1.28    341
# 140  2020-08-06  1755       1.67     438      1.67    218      1.65    388
# 141  2020-08-06  1755       2.40     438       2.4    388       2.4    363
# 142  2020-08-06  2000       1.88     440      1.83    390      1.83    365
# 143  2020-08-06  2000       2.58     440      2.58    365      2.58    342
# 144  2020-08-07  2000       1.40     464       1.4    414       1.4    389
# 145  2020-08-07  2000       1.70     414       1.7    389       1.7    366
# 146  2020-08-08  2000       1.55     488      1.55    438      1.55    413
# 147  2020-08-08  2000       1.60     488       1.6    438       1.6    413
# 148  2020-08-12  2000       3.20     584       3.2    534       3.2    509
# 149  2020-08-13  2000       3.30     608       3.3    558       3.3    533

# %%
df_all = pd.concat([df0,df1,df2],sort=False)

# %%
df_all.loc[(df_all['HT']=='CSKA Moscovo') & (df_all['AT']=='Tambov')]
# Out:
#     Unnamed: 0 League        Date  Time            HT      AT  ODDH  ODDD  \
# 39          39   RFPL  2020-07-22  1700  CSKA Moscovo  Tambov  1.28  4.15
# 26          26   RFPL  2020-07-22  1700  CSKA Moscovo  Tambov  1.22  4.45
# 42          42   RFPL  2020-07-22  1700  CSKA Moscovo  Tambov  1.26  4.65
#
#     ODDA ODD_25+ ODD_25- ODD_BthScore_Yes ODD_BthScore_No ODD_1X ODD_12  \
# 39  6.45    1.65    1.75             1.95             1.5   1.03   1.11
# 26  7.35    1.55    1.87             1.95             1.5   1.02   1.13
# 42  5.80    1.53     1.9             1.85            1.57   1.05   1.08
#
#    ODD_X2 Scrape_Date  Scrape_Time
# 39   2.98  2020-07-19         1145
# 26   3.30  2020-07-21         1354
# 42   3.05  2020-07-22         1450
